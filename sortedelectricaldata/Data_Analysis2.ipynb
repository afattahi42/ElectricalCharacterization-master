# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("datalogging/Data/ResistivityDCBiasSMU/resistivity1681430688.txt")

# %%
plt.scatter(data['trueGateDC'], data['x']*-1)

# %%
plt.scatter(data['t'], data['trueGateDC'])

# %%
data = pd.read_csv("datalogging/Data/HallEffectDCBias/hallDCBiasSMU1681453472.txt")
data
# Out:
#                t    i         x         y         r     theta  xK  tc  therm  \
# 0   1.681453e+09  3.2  0.000014 -0.000011  0.000018  317.0157   0   0      0
# 1   1.681453e+09 -3.2  0.000036 -0.000015  0.000040  332.7234   0   0      0
# 2   1.681454e+09  3.2  0.000011 -0.000008  0.000015  314.1784   0   0      0
# 3   1.681454e+09 -3.2  0.000037 -0.000018  0.000036  330.7487   0   0      0
# 4   1.681454e+09  3.2  0.000013 -0.000014  0.000018  322.5321   0   0      0
# 5   1.681454e+09 -3.2  0.000037 -0.000018  0.000043  332.7914   0   0      0
# 6   1.681454e+09  3.2 -0.000382  0.000050  0.000389  172.7538   0   0      0
# 7   1.681454e+09 -3.2 -0.000388  0.000049  0.000380  173.1322   0   0      0
# 8   1.681454e+09  3.2 -0.000403  0.000051  0.000407  173.9072   0   0      0
# 9   1.681454e+09 -3.2 -0.000349  0.000042  0.000349  173.8235   0   0      0
# 10  1.681454e+09  3.2 -0.000371  0.000048  0.000382  173.6168   0   0      0
# ...

# %%
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/HallEffectDCBias/hallDCBiasSMU1681453699.txt")

def avgHallSignal(data, dcList):
    #dcList = np.linspace(-200, 200, 21)
    dataP = data[data['i'] == 3.2]
    dataN = data[data['i'] == -3.2]
    avgP = []
    avgN = []

    for dc in dcList:
        dataDC = dataP[abs(dataP['dc'] - dc) < .1]
        avgX = np.mean(dataDC['x'])
        avgP += [avgX]
                  
    for dc in dcList:
        dataDC = dataN[abs(dataN['dc'] - dc) < .1]
        avgX = np.mean(dataDC['x'])
        avgN += [avgX]
    
    avgDiff = [avgP[i]-avgN[i] for i in range(len(avgP))]
    return avgDiff

# %%
plt.scatter(data['dc'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/HallEffectDCBias/hallDCBiasSMU1681453699.txt")

# %%
plt.scatter(data['t'], data['x'])

# %%
g = avgHallSignal(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17360\3399945132.py in <module>
# ----> 1 g = avgHallSignal(data)
#
# TypeError: avgHallSignal() missing 1 required positional argument: 'dcList'

# %%
dcList = np.linspace(-200, 200, 11)
plt.plot(dcList, g)

# %%
data = pd.read_csv("datalogging/Data/HallEffectDCBias/hallDCBiasSMU1681453699.txt")

# %%
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/HallSwap/hallSwap1681451741.txt")
plt.scatter(data['t'], data['x'])

# %%
dataP = data[data['i'] == 3.2]
dataN = data[data['i'] == -3.2]

# %%
np.mean(dataP['x'])-np.mean(dataN['x'])
# Out:
# -4.3057025340538835e-05

# %%
data = pd.read_csv("datalogging/Data/HallEffectDCBias/hallDCBiasSMU1681512471.txt")
plt.scatter(data['t'], data['x'])

# %%
g = avgHallSignal(data)
dcList = np.linspace(-200, 200, 21)
plt.scatter(dcList, g)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17360\2580057497.py in <module>
# ----> 1 g = avgHallSignal(data)
#       2 dcList = np.linspace(-200, 200, 21)
#       3 plt.scatter(dcList, g)
#
# TypeError: avgHallSignal() missing 1 required positional argument: 'dcList'

# %%
data

# %%
data = pd.read_csv("datalogging/Data/HallEffectDCBias/hallDCBiasSMU1681540416.txt")
plt.scatter(data['t'], data['x'])

# %%
g = avgHallSignal(data)
dcList = np.linspace(-200, 200, 21)
plt.scatter(dcList, g)

# %%
plt.scatter(data['t'], data['x2'])

# %%
plt.scatter(data['t'], data['dc'])

# %%
data = pd.read_csv("datalogging/Data/HallEffectDCBias/hallDCBiasSMU1681588071.txt")
plt.scatter(data['t'], data['x'])

# %%
plt.scatter(data['t'], data['dc'])

# %%
data['dc']
# Out:
# 0       0.000038
# 1       0.000038
# 2       0.000038
# 3       0.000038
# 4       0.000038
#           ...
# 3115    0.000101
# 3116    0.000101
# 3117    0.000101
# 3118    0.000101
# 3119    0.000101
# Name: dc, Length: 3120, dtype: float64

# %%
data['curr'] = data['x2']/10**5
dcList = np.linspace(-50, 50, 25)
g = avgHallSignal(data, dcList)
plt.scatter(dcList, g)
plt.ylabel('hall signal (V)')
plt.xlabel('DC bias')
# Out:
# Text(0.5, 0, 'DC bias')

# %%
plt.plot(data['curr'])

# %%
data['dc']
# Out:
# 0       0.000038
# 1       0.000038
# 2       0.000038
# 3       0.000038
# 4       0.000038
#           ...
# 3115    0.000101
# 3116    0.000101
# 3117    0.000101
# 3118    0.000101
# 3119    0.000101
# Name: dc, Length: 3120, dtype: float64

# %%
plt.scatter(data['dc'], data['curr'])

# %%
data = pd.read_csv("datalogging/Data/HalLSwap/hallSwap1681661681.txt")
plt.scatter(data['t'], data['x'])

# %%
upD = data[data['i'] == 3.2]
downD = data[data['i'] == -3.2]

up = np.mean(upD['x'])
down = np.mean(downD['x'])
print(up-down)
# Out:
# -1.515014994522189e-05

# %%
data = pd.read_csv("datalogging/Data/Resistivity/resistivity1681777364.txt")
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/tempControl/pidTemp1681777348.txt")
data
# Out:
#                  t          i  temp_desired                       temp_tc  \
# 0     1.681777e+09  28.396921           0.0   28.234741225.94791094225151
# 1     1.681777e+09  28.313647           0.0   28.101531925.79269359275055
# 2     1.681777e+09  28.230257           0.0   27.979291925.64581505492592
# 3     1.681777e+09  28.146736           0.0   27.867803525.49341647921057
# 4     1.681777e+09  28.063171           0.0  27.756578425.346843708342078
# ...            ...        ...           ...                           ...
# 1813  1.681786e+09  27.000000           0.0  26.565698622.732144883227907
# 1814  1.681786e+09  27.000000           0.0   26.514497722.65454125913979
# 1815  1.681786e+09  27.000000           0.0  26.447778722.581662878826506
# 1816  1.681787e+09  27.000000           0.0  26.389839122.506125956336884
# 1817  1.681787e+09  27.000000           0.0  26.319684922.431968737104395
#
#       temp_therm  res_therm
# 0     1037.89758        NaN
# ...

# %%
plt.scatter(data['t'], data['temp_therm'])

# %%
plt.scatter(data['t'], data['temp_tc'])

# %%
dataR = pd.read_csv("datalogging/Data/Resistivity/resistivity1681788651.txt")
dataT = pd.read_csv("datalogging/Data/tempControl/pidTemp1681788639.txt")

# %%
plt.scatter(dataR['t'], dataR['x'])

# %%
plt.scatter(dataT['t'], dataT['temp_tc'])

# %%
plt.scatter(dataT['t'], dataT['temp_therm'])
plt.scatter(dataT['t'], dataT['temp_tc'])

# %%
dataT
# Out:
#                   t          i  temp_desired    temp_tc  temp_therm  \
# 0      1.681789e+09  23.417587      0.010609  23.437664   18.102837
# 1      1.681789e+09  23.417587      0.015424  23.445879   18.100950
# 2      1.681789e+09  23.417587      0.015231  23.444160   18.097378
# 3      1.681789e+09  23.417587      0.013540  23.439670   18.092470
# 4      1.681789e+09  23.417587      0.008909  23.429798   18.091730
# ...             ...        ...           ...        ...         ...
# 10826  1.681930e+09  27.917479      0.447976  27.519499   21.008106
# 10827  1.681930e+09  28.000952      0.457405  27.603964   21.083659
# 10828  1.681930e+09  28.085103      0.460433  27.701477   21.163311
# 10829  1.681930e+09  28.167938      0.457198  27.808636   21.247023
# 10830  1.681930e+09  28.251339      0.453964  27.915306   21.338390
#
#         res_therm
# 0      1014.44781
# 1      1014.44220
# 2      1014.43158
# 3      1014.41699
# 4      1014.41479
# ...           ...
# ...

# %%
rang = 5000
plt.scatter(dataT['t'][0:rang], dataT['temp_therm'][0:rang], label = 'therm')
plt.legend()

# %%
plt.scatter(dataT['t'], dataT['res_therm'])

# %%
data = pd.read_csv("datalogging/Data/HallEffectDCBias/hallDCBiasSMU1682023199.txt")
plt.scatter(data['t'], data['x'])

# %%
data
# Out:
#                  t    i         x             y         r      theta  xK  tc  \
# 0     1.682023e+09  3.2 -0.000004  1.430260e-06  0.000004  164.92230   0   0
# 1     1.682023e+09 -3.2  0.000005  1.430260e-06  0.000005   16.79547   0   0
# 2     1.682023e+09  3.2 -0.000003  1.430260e-06  0.000002  148.96680   0   0
# 3     1.682023e+09 -3.2  0.000004  9.917608e-07  0.000004   16.42062   0   0
# 4     1.682023e+09  3.2 -0.000003  1.137927e-06  0.000004  163.08920   0   0
# ...            ...  ...       ...           ...       ...        ...  ..  ..
# 1298  1.682032e+09  3.2 -0.000297 -9.679344e-05  0.000312  197.99530   0   0
# 1299  1.682032e+09 -3.2 -0.000743 -9.874071e-05  0.000749  273.28860   0   0
# 1300  1.682032e+09  3.2 -0.000023 -9.691363e-05  0.001014  198.04710   0   0
# 1301  1.682032e+09 -3.2  0.000005 -1.200133e-04  0.000124  273.23990   0   0
# 1302  1.682032e+09  3.2 -0.000016 -1.200133e-04  0.000122  262.76110   0   0
#
# ...

# %%
def avgHallSignal(data):
    dcList = data['trueGateDC'].unique()
    dataP = data[data['i'] == 3.2]
    dataN = data[data['i'] == -3.2]
    avgP = []
    avgN = []

    for dc in dcList:
        dataDC = dataP[abs(dataP['trueGateDC'] - dc) < .1]
        avgX = np.mean(dataDC['x'])
        linOffset = (dataDC[-1]-dataDC[0])/(len(dataDC)*2)
        avgP += [avgX]
                  
    for dc in dcList:
        dataDC = dataN[abs(dataN['trueGateDC'] - dc) < .1]
        avgX = np.mean(dataDC['x'])
        avgN += [avgX]
    
    avgDiff = [avgP[i]-avgN[i]-linOffset for i in range(len(avgP))]
    return avgDiff

# %%
data['curr'] = data['x2']/10**5
dcList = np.linspace(-120, 120, 59)
g = avgHallSignal2(data, dcList)
plt.scatter(dcList, g)
plt.ylabel('hall signal (V)')
plt.xlabel('DC bias')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17360\3977432924.py in <module>
#       1 data['curr'] = data['x2']/10**5
#       2 dcList = np.linspace(-120, 120, 59)
# ----> 3 g = avgHallSignal2(data, dcList)
#       4 plt.scatter(dcList, g)
#       5 plt.ylabel('hall signal (V)')
#
# NameError: name 'avgHallSignal2' is not defined

# %%
data['trueGateDC']
# Out:
# 0        0.000045
# 1        0.000045
# 2        0.000045
# 3        0.000045
# 4        0.000045
#           ...
# 1298    86.899830
# 1299    86.899830
# 1300    86.899830
# 1301    86.899830
# 1302    86.899830
# Name: trueGateDC, Length: 1303, dtype: float64

# %%
data = pd.read_csv("datalogging/Data/HallEffectDCBias/hallDCBiasSMU1682034656.txt")
plt.scatter(data['t'], data['x'])
plt.scatter(data['t'], data['trueGateI']*100)

# %%
plt.scatter(data['t'], data['trueGateI'])

# %%
data['curr'] = data['x2']/10**5
dcList = np.linspace(-120, 120, 59)
g = avgHallSignal2(data, dcList)
plt.scatter(dcList, g)
plt.ylabel('hall signal (V)')
plt.xlabel('DC bias')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17360\3977432924.py in <module>
#       1 data['curr'] = data['x2']/10**5
#       2 dcList = np.linspace(-120, 120, 59)
# ----> 3 g = avgHallSignal2(data, dcList)
#       4 plt.scatter(dcList, g)
#       5 plt.ylabel('hall signal (V)')
#
# NameError: name 'avgHallSignal2' is not defined

# %%
dataT = pd.read_csv("datalogging/Data/tempControl/fixedTemp1681930121.txt")

# %%
dataT
# Out:
#                    t   i  temp_desired    temp_tc
# 0       1.681930e+09  18           2.0  24.130606
# 1       1.681930e+09  18           2.0  24.113075
# 2       1.681930e+09  18           2.0  24.090080
# 3       1.681930e+09  18           2.0  24.076889
# 4       1.681930e+09  18           2.0  24.073931
# ...              ...  ..           ...        ...
# 124026  1.682053e+09  18           2.0  24.396475
# 124027  1.682053e+09  18           2.0  24.395039
# 124028  1.682053e+09  18           2.0  24.396414
# 124029  1.682053e+09  18           2.0  24.397139
# 124030  1.682053e+09  18           2.0  24.410768
#
# [124031 rows x 4 columns]

# %%
plt.scatter(dataT['t'], dataT['temp_tc'])

# %%
plt.scatter(data['t'][-2000:], data['x'][-2000:])

# %%
data.iloc[3800]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17360\3374653183.py in <module>
# ----> 1 data.iloc[3800]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1521
#    1522             # validate the location
# -> 1523             self._validate_integer(key, axis)
#    1524
#    1525             return self.obj._ixs(key, axis=axis)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1453         len_axis = len(self.obj._get_axis(axis))
# ...

# %%
data['trueGateDC'].unique()

# %%
data['trueGateI'].unique()

# %%
plt.scatter(data['trueGateDC'], data['trueGateI'])

# %%
plt.scatter(data['t'], data['trueGateDC'])

# %%
data = pd.read_csv("datalogging/Data/HallEffectDCBias/hallDCBiasSMU1682053940.txt")
plt.scatter(data['t'], data['x'])
plt.scatter(data['t'], data['trueGateI']*100)

# %%
plt.scatter(data['trueGateDC'], data['trueGateI'])

# %%
data['curr'] = data['x2']/10**5
dcList = data['trueGateDC'].unique()
g = avgHallSignal(data)
plt.scatter(dcList, g)
plt.ylabel('hall signal (V)')
plt.xlabel('DC bias')
# Out:
# Text(0.5, 0, 'DC bias')

# %%
data = pd.read_csv("datalogging/Data/HallEffectDCBias/hallDCBiasSMU1682266954.txt")
plt.scatter(data['t'], data['x'])
plt.scatter(data['t'], data['trueGateI']*100)

# %%
plt.scatter(data['t'], data['trueGateI'])

# %%
plt.scatter(data['t'], data['trueGateDC'])

# %%
list(data['x'][:2])[-1]
# Out:
# 2.489421e-06

# %%
def avgHallSignal(data):
    dcList = data['trueGateDC'].unique()
    dataP = data[data['i'] == 3.2]
    dataN = data[data['i'] == -3.2]
    avgP = []
    avgN = []

    for dc in dcList:
        dataDC = dataP[abs(dataP['trueGateDC'] - dc) < .1]
        avgX = np.mean(dataDC['x'])
        avgP += [avgX]
                  
    for dc in dcList:
        dataDC = dataN[abs(dataN['trueGateDC'] - dc) < .1]
        avgX = np.mean(dataDC['x'])
        #linOffset = (list(dataDC['x'])[-1]-list(dataDC['x'])[0])/(len(dataDC)*2)
        #linOffset = 0
        linOffset = 0
        avgN += [avgX-linOffset]
    
    avgDiff = [avgP[i]-avgN[i] for i in range(len(avgP))]
    return avgDiff

# %%
## data['curr'] = data['x2']/10**5

data1 = pd.DataFrame.append(data[:3601],data[10981:])
data2 = data[3601:10981]


dcList1 = data1['trueGateDC'].unique()
g1 = avgHallSignal(data1)

dcList2 = data2['trueGateDC'].unique()
g2 = avgHallSignal(data2)

plt.scatter(dcList1, g1, label = 'up')
plt.scatter(dcList2, g2, label= 'down')

plt.legend()
plt.ylabel('hall signal (V)')
plt.xlabel('DC bias')
# Out:
# C:\Users\matth\AppData\Local\Temp\ipykernel_17360\2256320002.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data1 = pd.DataFrame.append(data[:3601],data[10981:])
# Text(0.5, 0, 'DC bias')

# %%
plt.scatter(data['t'][3100:3200], data['x'][3100:3200])

# %%
plt.scatter(data['t'][3100:3200], data['trueGateI'][3100:3200])

# %%
data[3600:3720]
# Out:
#                  t    i         x         y         r     theta  xK  tc  \
# 3600  1.682291e+09  3.2  0.000016 -0.000072  0.000075  282.0618   0   0
# 3601  1.682291e+09 -3.2 -0.000008 -0.000073  0.000074  260.4052   0   0
# 3602  1.682291e+09  3.2  0.000013 -0.000074  0.000075  279.8569   0   0
# 3603  1.682291e+09 -3.2 -0.000021 -0.000074  0.000076  253.3293   0   0
# 3604  1.682291e+09  3.2  0.000004 -0.000073  0.000074  271.9467   0   0
# ...            ...  ...       ...       ...       ...       ...  ..  ..
# 3715  1.682292e+09 -3.2 -0.000055 -0.000082  0.000100  234.3970   0   0
# 3716  1.682292e+09  3.2 -0.000037 -0.000083  0.000090  246.3341   0   0
# 3717  1.682292e+09 -3.2 -0.000054 -0.000082  0.000100  234.7794   0   0
# 3718  1.682292e+09  3.2 -0.000039 -0.000083  0.000092  244.2602   0   0
# 3719  1.682292e+09 -3.2 -0.000070 -0.000082  0.000109  231.3827   0   0
#
#       therm  trueGateDC     trueGateI        x2        y2        r2  theta2
# ...

# %%
plt.scatter(data['t'], data['x2'])

# %%
# Run 2 of working gate bias one E2?

# %%
fullData = []

# %%
data = pd.read_csv("datalogging/Data/HallEffectDCBias/hallDCBiasSMU1682369367.txt")
plt.scatter(data['t'], data['x'])
plt.scatter(data['t'], data['trueGateI']*100)

# %%
plt.scatter(data['t'], data['trueGateI'])

# %%
vSweepData = []
vSweepData += [data]
data['curr'] = data['x2']/10**5
data['samp_res'] = (1-data['x2'])/data['curr']

data1 = pd.DataFrame(data[:611])
data2 = data[611:]


dcList1 = data1['trueGateDC'].unique()
g1 = avgHallSignal(data1)

dcList2 = data2['trueGateDC'].unique()
g2 = avgHallSignal(data2)

#g1 = [1/g1[i] for i in range(len(g1))]


#g2 = [1/g2[i] for i in range(len(g2))]
plt.scatter(dcList1, g1, label = 'up', color = 'gold')
plt.scatter(dcList2, g2, label= 'down', color = 'green')

plt.legend()
plt.title('Hall Voltage vs Gate Bias')
plt.ylabel('hall signal (V)')
plt.xlabel('DC bias')

fullData += [[[dcList1, g1], [dcList2, g2]]]

# %%
plt.title('Sample Resistance vs Gate Bias')
plt.scatter(data['trueGateDC'], data['samp_res'])
data1 = pd.DataFrame(data[:611])
data2 = data[611:]
plt.scatter(data1['trueGateDC'], data1['samp_res'], color = 'gold', label = 'up')
plt.scatter(data2['trueGateDC'], data2['samp_res'], color= 'green', label = 'down')
plt.legend()
plt.xlabel('gate bias (V)')
plt.ylabel('Resistance of Sample (ohms)')
# Out:
# Text(0, 0.5, 'Resistance of Sample (ohms)')

# %%
data[:622]
# Out:
#                 t    i         x         y         r     theta  xK  tc  therm  \
# 0    1.682369e+09  3.2 -0.000004 -0.000005  0.000007  232.1934   0   0      0
# 1    1.682369e+09 -3.2  0.000005 -0.000006  0.000008  311.6089   0   0      0
# 2    1.682369e+09  3.2 -0.000004 -0.000005  0.000006  232.1934   0   0      0
# 3    1.682369e+09 -3.2  0.000003 -0.000005  0.000007  315.8750   0   0      0
# 4    1.682369e+09  3.2 -0.000003 -0.000005  0.000007  243.5022   0   0      0
# ..            ...  ...       ...       ...       ...       ...  ..  ..    ...
# 617  1.682374e+09 -3.2 -0.000044 -0.000037  0.000053  224.2254   0   0      0
# 618  1.682374e+09  3.2 -0.000038 -0.000037  0.000053  224.1948   0   0      0
# 619  1.682374e+09 -3.2 -0.000048 -0.000037  0.000057  217.4226   0   0      0
# 620  1.682374e+09  3.2  0.000010 -0.000040  0.000043  281.4734   0   0      0
# 621  1.682374e+09 -3.2 -0.000007 -0.000041  0.000042  252.9734   0   0      0
#
# ...

# %%
plt.scatter(data['t'], data['x2'])

# %%
data = pd.read_csv("datalogging/Data/HallEffectDCBias/hallDCBiasSMU1682384888.txt")
plt.scatter(data['t'], data['x'])
plt.scatter(data['t'], data['trueGateI']*100)

# %%
data['curr'] = data['x2']/10**5
data['samp_res'] = (1-data['x2'])/data['curr']

data1 = pd.DataFrame(data[:1221])
data2 = data[1221:]


dcList1 = data1['trueGateDC'].unique()
g1 = avgHallSignal(data1)

dcList2 = data2['trueGateDC'].unique()
g2 = avgHallSignal(data2)

#g1 = [1/g1[i] for i in range(len(g1))]


#g2 = [1/g2[i] for i in range(len(g2))]
plt.scatter(dcList1, g1, label = 'up', color = 'gold')
plt.scatter(dcList2, g2, label= 'down', color = 'green')

plt.legend()
plt.title('Hall Voltage vs Gate Bias')
plt.ylabel('hall signal (V)')
plt.xlabel('DC bias')
fullData += [[[dcList1, g1], [dcList2, g2]]]
vSweepData += [data]

# %%
plt.scatter(fullData[0][0][0], fullData[0][0][1], label = 'up, spd = 1', c = '#ff0000')
plt.scatter(fullData[0][1][0], fullData[0][1][1], label= 'down, spd = 1', color = '#0002ff')
plt.scatter(fullData[1][0][0], fullData[1][0][1], label = 'up, spd = .5', color = '#b30500')
plt.scatter(fullData[1][1][0], fullData[1][1][1], label= 'down, spd = .5', color = '#0002aa')
plt.legend()
# https://www.w3schools.com/colors/colors_rgb.asp

# %%
data = pd.read_csv("datalogging/Data/HallEffectDCBias/hallDCBiasSMU1682416986.txt")
plt.scatter(data['t'], data['x'])
plt.scatter(data['t'], data['trueGateI']*100)

# %%
data['curr'] = data['x2']/10**5
data['samp_res'] = (1-data['x2'])/data['curr']

data1 = pd.DataFrame(data[:1221])
data2 = data[1221:]


dcList1 = data1['trueGateDC'].unique()
g1 = avgHallSignal(data1)

dcList2 = data2['trueGateDC'].unique()
g2 = avgHallSignal(data2)

#g1 = [1/g1[i] for i in range(len(g1))]


#g2 = [1/g2[i] for i in range(len(g2))]
plt.scatter(dcList1, g1, label = 'up', color = 'gold')
plt.scatter(dcList2, g2, label= 'down', color = 'green')

plt.legend()
plt.title('Hall Voltage vs Gate Bias')
plt.ylabel('hall signal (V)')
plt.xlabel('DC bias')
fullData += [[[dcList1, g1], [dcList2, g2]]]
vSweepData +=[data]

# %%
plt.scatter(vSweepData[0]['trueGateDC'], vSweepData[0]['samp_res'], label = str(320/((list(vSweepData[0]['t'])[-1]-list(vSweepData[0]['t'])[0])/60))[:3] + " Volts/Min", s =5  )
plt.scatter(vSweepData[1]['trueGateDC'], vSweepData[1]['samp_res'], label = str(320/((list(vSweepData[1]['t'])[-1]-list(vSweepData[1]['t'])[0])/60))[:3] + " Volts/Min", s =5)
plt.scatter(vSweepData[2]['trueGateDC'], vSweepData[2]['samp_res'] ,label = str(320/((list(vSweepData[2]['t'])[-1]-list(vSweepData[2]['t'])[0])/60))[:3] + " Volts/Min", s=5)
plt.legend(title = "sweep rate")

# %%
# temp data

# %%
# 25 C
data1 = pd.read_csv("datalogging/Data/HallEffectDCBias/hallDCBiasSMU1682462469.txt")
plt.scatter(data1['t'], data1['x'])
plt.scatter(data1['t'], data1['trueGateI']*100)

# %%
# 60 C
data2 = pd.read_csv("datalogging/Data/HallEffectDCBias/hallDCBiasSMU1682474583.txt")
plt.scatter(data2['t'], data2['x'])
plt.scatter(data2['t'], data2['trueGateI']*100)

# %%
plt.scatter(data1['trueGateDC'], data1['x2'])
plt.scatter(data2['trueGateDC'], data2['x2'])

# %%
plt.scatter(data1['trueGateDC'], data1['x2'])
plt.scatter(data2['trueGateDC'], data2['x2'])
plt.scatter(data3['trueGateDC'], data3['x2'])

# %%
dataA = data1[:611]
dataB = data1[611:]


dcList1 = dataA['trueGateDC'].unique()
g1 = avgHallSignal(dataA)

dcList2 = dataB['trueGateDC'].unique()
g2 = avgHallSignal(dataB)

#g1 = [1/g1[i] for i in range(len(g1))]


#g2 = [1/g2[i] for i in range(len(g2))]
plt.scatter(dcList1, g1, label = 'up', color = 'gold')
plt.scatter(dcList2, g2, label= 'down', color = 'green')

plt.legend()
plt.title('Hall Voltage vs Gate Bias')
plt.ylabel('hall signal (V)')
plt.xlabel('DC bias')
# Out:
# Text(0.5, 0, 'DC bias')

# %%
dataA = data2[:611]
dataB = data2[611:]


dcList1 = dataA['trueGateDC'].unique()
g1 = avgHallSignal(dataA)

dcList2 = dataB['trueGateDC'].unique()
g2 = avgHallSignal(dataB)

#g1 = [1/g1[i] for i in range(len(g1))]


#g2 = [1/g2[i] for i in range(len(g2))]
plt.scatter(dcList1, g1, label = 'up', color = 'gold')
plt.scatter(dcList2, g2, label= 'down', color = 'green')

plt.legend()
plt.title('Hall Voltage vs Gate Bias')
plt.ylabel('hall signal (V)')
plt.xlabel('DC bias')
# Out:
# Text(0.5, 0, 'DC bias')

# %%
#60 redo:

# %%
data3 = pd.read_csv("datalogging/Data/HallEffectDCBias/hallDCBiasSMU1682495764.txt") # 60 C
data4 = pd.read_csv("datalogging/Data/HallEffectDCBias/hallDCBiasSMU1682529695.txt") # 10 C
data5 = pd.read_csv("datalogging/Data/HallEffectDCBias/hallDCBiasSMU1682541631.txt") # 25 C
data6= pd.read_csv("datalogging/Data/HallEffectDCBias/hallDCBiasSMU1682564523.txt") # 45 C

i = 10/10**6
plt.scatter(data3['trueGateDC'], data3['x2']/-i, label = '60 C', s= 5)
plt.scatter(data4['trueGateDC'], data4['x2']/-i, label = '10 C', s =5)
plt.scatter(data5['trueGateDC'], data5['x2']/-i, label = '30 C', s =5 )
#plt.scatter(data6['trueGateDC'], data6['x2'], label = '45 C', s =5 )
plt.legend()

# %%
dataA = data3[:611]
dataB = data3[611:]


dcList13 = dataA['trueGateDC'].unique()
g13 = avgHallSignal(dataA)

dcList23 = dataB['trueGateDC'].unique()
g23 = avgHallSignal(dataB)

#g1 = [1/g1[i] for i in range(len(g1))]


#g2 = [1/g2[i] for i in range(len(g2))]
plt.scatter(dcList13, g13, label = 'up', color = 'gold')
plt.scatter(dcList23, g23, label= 'down', color = 'green')

plt.legend()
plt.title('Hall Voltage vs Gate Bias, 60 C')
plt.ylabel('hall signal (V)')
plt.xlabel('DC bias')
# Out:
# Text(0.5, 0, 'DC bias')

# %%
dataA = data4[:611]
dataB = data4[611:]


dcList14 = dataA['trueGateDC'].unique()
g14 = avgHallSignal(dataA)

dcList24 = dataB['trueGateDC'].unique()
g24 = avgHallSignal(dataB)

#g1 = [1/g1[i] for i in range(len(g1))]


#g2 = [1/g2[i] for i in range(len(g2))]
plt.scatter(dcList14, g14, label = 'up', color = 'gold')
plt.scatter(dcList24, g24, label= 'down', color = 'green')

plt.legend()
plt.title('Hall Voltage vs Gate Bias 10 C')
plt.ylabel('hall signal (V)')
plt.xlabel('DC bias')
# Out:
# Text(0.5, 0, 'DC bias')

# %%
dataA = data5[:611]
dataB = data5[611:]


dcList15 = dataA['trueGateDC'].unique()
g15 = avgHallSignal(dataA)

dcList25 = dataB['trueGateDC'].unique()
g25 = avgHallSignal(dataB)

#g1 = [1/g1[i] for i in range(len(g1))]


#g2 = [1/g2[i] for i in range(len(g2))]
plt.scatter(dcList15, g15, label = 'up', color = 'gold')
plt.scatter(dcList25, g25, label= 'down', color = 'green')

plt.legend()
plt.title('Hall Voltage vs Gate Bias 10 C')
plt.ylabel('hall signal (V)')
plt.xlabel('DC bias')
# Out:
# Text(0.5, 0, 'DC bias')

# %%
plt.plot(dcList13, g13, label = '25 C', color = 'aqua')
plt.plot(dcList23, g23, color = 'aqua')

plt.plot(dcList14, g14, label = '60 C', color = 'darkorange')
plt.plot(dcList24, g24, color = 'darkorange')

plt.plot(dcList15, g15, color = 'darkolivegreen')
plt.plot(dcList25, g25, label= '10 C', color = 'darkolivegreen')
plt.legend()

# %%
plt.scatter(data6['t'], data6['x2'], label = '45 C', s =5 )

# %%
plt.scatter(data6['trueGateDC'], data6['x2'], label = '45 C', s =5 )

# %%
plt.scatter(data6['trueGateDC'], data6['trueGateI'], label = '45 C', s =5 )

# %%
dataA = data6[:611]
dataB = data6[611:]


dcList15 = dataA['trueGateDC'].unique()
g15 = avgHallSignal(dataA)

dcList25 = dataB['trueGateDC'].unique()
g25 = avgHallSignal(dataB)

#g1 = [1/g1[i] for i in range(len(g1))]


#g2 = [1/g2[i] for i in range(len(g2))]
plt.scatter(dcList15, g15, label = 'up', color = 'gold')
plt.scatter(dcList25, g25, label= 'down', color = 'green')

plt.legend()
plt.title('Hall Voltage vs Gate Bias 10 C')
plt.ylabel('hall signal (V)')
plt.xlabel('DC bias')
# Out:
# Text(0.5, 0, 'DC bias')

# %%
plt.scatter(data6['t'], data6['x'], label = '45 C', s =5 )
